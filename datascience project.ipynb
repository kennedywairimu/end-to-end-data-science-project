# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Movie_regression (1).csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
df.hist (bins = 15, color= "r", edgecolor ="black", xlabelsize = 8, ylabelsize = 8, linewidth = 1, grid = False)

plt.tight_layout (rect = (0,0, 1.2,1.2))

plt.suptitle ("Movie Regression Univariate analysis", x = 0.65, y= 1.25)
plt.show()

# %%
plt.scatter (df["Collection"], df["Trailer_views"], color = "red")

plt.xlabel ("Trailer_views")
plt.ylabel ("Collection")
plt.show ()

# %%
sns.boxplot (x = "3D_available", y = "Collection", data = df, palette = "colorblind")
# Out:
# <Axes: xlabel='3D_available', ylabel='Collection'>

# %%
sns.boxplot (x = "Genre", y = "Collection", data = df, palette = "colorblind")
# Out:
# <Axes: xlabel='Genre', ylabel='Collection'>

# %%
corr = df.corr()
corr
# Out:
# C:\Users\KENNEDY\AppData\Local\Temp\ipykernel_12824\2438084875.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#                      Marketing expense  Production expense  \
# Marketing expense             1.000000            0.406583
# Production expense            0.406583            1.000000
# Multiplex coverage           -0.420972           -0.763651
# Budget                       -0.219247           -0.391676
# Movie_length                  0.352734            0.644779
# Lead_ Actor_Rating            0.380050            0.706481
# Lead_Actress_rating           0.379813            0.707956
# Director_rating               0.380069            0.707566
# Producer_rating               0.376462            0.705819
# Critic_rating                -0.184985           -0.251565
# ...

# %%
plt.figure (figsize = (12, 10))
sns.heatmap (corr, annot = True, fmt = ".2f", cmap = "coolwarm_r", linewidth = 0.2)

plt.title ("movie regression multivariate plot", fontsize = 14)
plt.show ()

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
df.Time_taken = df.Time_taken.fillna(df.Time_taken.mean ())

# %%
df["avg_rating"] = (df["Lead_ Actor_Rating"] + df["Lead_Actress_rating"] + df["Director_rating"] + df["Producer_rating"])/4

# %%
del df["Lead_ Actor_Rating"]
del df["Lead_Actress_rating"]
del df["Director_rating"]
del df["Producer_rating"]

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Marketing expense   506 non-null    float64
#  1   Production expense  506 non-null    float64
#  2   Multiplex coverage  506 non-null    float64
#  3   Budget              506 non-null    float64
#  4   Movie_length        506 non-null    float64
#  5   Critic_rating       506 non-null    float64
#  6   Trailer_views       506 non-null    int64
#  7   3D_available        506 non-null    object
#  8   Time_taken          506 non-null    float64
#  9   Twitter_hastags     506 non-null    float64
#  10  Genre               506 non-null    object
#  11  Avg_age_actors      506 non-null    int64
#  12  Num_multiplex       506 non-null    int64
#  13  Collection          506 non-null    int64
#  14  avg_rating          506 non-null    float64
# ...

# %%
df = pd.get_dummies (df, columns = ["Genre", "3D_available"])
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# 0         138.7           7.94         527367      109.60          223.840
# 1         152.4           7.44         494055      146.64          243.456
# 2         134.6           7.44         547051      147.88         2022.400
# 3         119.3           8.26         516279      185.36          225.344
# 4         127.7           8.26         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Collection  avg_rating  Genre_Action  \
# ...

# %%
del df["3D_available_NO"]

# %%
df.hist (bins = 15, color= "r", edgecolor ="black", xlabelsize = 8, ylabelsize = 8, linewidth = 1, grid = False)

plt.tight_layout (rect = (0,0, 1.2,1.2))

plt.suptitle ("Movie Regression Univariate analysis", x = 0.65, y= 1.25)
plt.show ()

# %%
plt.scatter (df["Collection"], df["Marketing expense"], color = "red")

# %%
plt.scatter (df["Collection"], df["Twitter_hastags"], color = "red")

# %%
plt.scatter (df["Collection"], df["Avg_age_actors"], color = "red")

# %% [markdown]
# ####observation
#  Time_taken
#  Twitter_hastags
#  Avg_age_actors

# %%
def p_outliers (df, col):
    upper_limit = np.percentile (df[col], [99]) * 3
    lower_limit = np.percentile (df[col], [1]) *0.3
    
    return f"upper_limit:{upper_limit} --- lower_limit: {lower_limit}"

# %%
p_outliers (df, "Time_taken")
# Out:
# 'upper_limit:[637.206] --- lower_limit: [32.025]'

# %%
df.Time_taken[(df.Time_taken > 637.2) | (df.Time_taken < 32)] = df.Time_taken.mean ()
# Out:
# C:\Users\KENNEDY\AppData\Local\Temp\ipykernel_12824\3238506291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Time_taken[(df.Time_taken > 637.2) | (df.Time_taken < 32)] = df.Time_taken.mean ()

# %%
df.Time_taken[(df.Time_taken > 637.2) | (df.Time_taken < 32)]
# Out:
# Series([], Name: Time_taken, dtype: float64)

# %%
p_outliers (df, "Twitter_hastags")
# Out:
# 'upper_limit:[923.9712] --- lower_limit: [60.52848]'

# %%
df.Twitter_hastags[(df.Twitter_hastags > 923) | (df.Twitter_hastags < 60.5)]
# Out:
# 2      2022.4
# 423    1622.4
# Name: Twitter_hastags, dtype: float64

# %%
df.Twitter_hastags[(df.Twitter_hastags > 923) | (df.Twitter_hastags < 60.5)] = df.Twitter_hastags.mean ()
# Out:
# C:\Users\KENNEDY\AppData\Local\Temp\ipykernel_12824\3494183956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Twitter_hastags[(df.Twitter_hastags > 923) | (df.Twitter_hastags < 60.5)] = df.Twitter_hastags.mean ()

# %%
p_outliers (df, "Avg_age_actors")
# Out:
# 'upper_limit:[180.] --- lower_limit: [6.]'

# %%
df.Avg_age_actors[(df.Avg_age_actors > 180) | (df.Avg_age_actors < 6)]
# Out:
# 213    3
# Name: Avg_age_actors, dtype: int64

# %%
df.Avg_age_actors[(df.Avg_age_actors > 180) | (df.Avg_age_actors < 6)] = df.Avg_age_actors.mean ()
# Out:
# C:\Users\KENNEDY\AppData\Local\Temp\ipykernel_12824\3472884447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Avg_age_actors[(df.Avg_age_actors > 180) | (df.Avg_age_actors < 6)] = df.Avg_age_actors.mean ()

# %% [markdown]
# machine learning

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Marketing expense   506 non-null    float64
#  1   Production expense  506 non-null    float64
#  2   Multiplex coverage  506 non-null    float64
#  3   Budget              506 non-null    float64
#  4   Movie_length        506 non-null    float64
#  5   Critic_rating       506 non-null    float64
#  6   Trailer_views       506 non-null    int64
#  7   Time_taken          506 non-null    float64
#  8   Twitter_hastags     506 non-null    float64
#  9   Avg_age_actors      506 non-null    float64
#  10  Num_multiplex       506 non-null    int64
#  11  Collection          506 non-null    int64
#  12  avg_rating          506 non-null    float64
#  13  Genre_Action        506 non-null    uint8
#  14  Genre_Comedy        506 non-null    uint8
# ...

# %%
y = df["Collection"]
y
# Out:
# 0      48000
# 1      43200
# 2      69400
# 3      66800
# 4      72400
#        ...
# 501    44800
# 502    41200
# 503    47800
# 504    44000
# 505    38000
# Name: Collection, Length: 506, dtype: int64

# %%
x = df.drop("Collection", axis=1)
x
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 477           320.4680               91.20              0.3860  29463.720
# 15             32.5478               71.28              0.4620  32407.870
# 332            20.6932               67.12              0.5621  33502.205
# 423           161.0084               91.20              0.3860  33902.165
# 19             34.5160               71.28              0.4620  31813.485
# ..                 ...                 ...                 ...        ...
# 106            23.4240               72.12              0.4800  32418.980
# 270            25.9832               68.92              0.5360  32530.080
# 348            20.3002               59.02              0.5650  36857.425
# 435           243.2080               91.20              0.2600  36824.095
# 102            24.5752               72.12              0.4800  35579.775
#
#      Movie_length  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
x_test
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 173            21.8356               63.10               0.490  35640.880
# 274            21.1288               67.82               0.553  37540.690
# 491            22.1148              110.48               0.391  33235.565
# 72             21.8328               76.62               0.587  33691.075
# 452           121.8034               91.20               0.287  34979.835
# ..                 ...                 ...                 ...        ...
# 412           396.2200               91.20               0.403  25708.540
# 436           308.4160               91.20               0.260  35890.855
# 411           301.0140               91.20               0.403  36979.635
# 86             21.0376               63.98               0.551  33413.325
# 75             21.9024               80.66               0.563  34918.730
#
#      Movie_length  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred= lr.predict(x_test)
y_lr_train_pred
# Out:
# array([19886.05611036, 43474.30540232, 48123.55197132, 32670.51594228,
#        38954.64137151, 57759.89117129, 43693.19478145, 52719.80219036,
#        22031.44015594, 45651.05959448, 45796.36826218, 53118.51217327,
#        59455.64915079, 35384.12604516, 73306.60588609, 35774.42969229,
#        44007.36663173, 57846.61456561, 31107.62544092, 49967.74660875,
#        15808.19890667, 43839.41315249, 52711.86467463, 48894.45563229,
#        50021.04639388, 72949.47240105, 42419.31569575, 75422.03147649,
#        24929.94222235, 53523.93190309, 37314.64083266, 46222.62836667,
#        18749.60682719, 49514.42188017, 47399.1629112 , 60288.33274652,
#        63631.10733409, 38343.06908822, 34706.21193185, 56671.45813735,
#        42453.22445071, 22872.3915636 , 12445.1148712 , 47807.02592493,
#        42077.77559146, 33453.06083554, 32049.57228026, 81637.82782675,
#        36386.19393872, 36608.85736106, 50520.30150851, 45690.42294482,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
lr_results = pd.DataFrame(('Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2)).transpose()
lr_results
# Out:
#                    0                1         2                 3         4
# 0  Linear regression  99780339.190658  0.711292  118548810.267941  0.598108

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred= rf.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(('Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2)).transpose()
rf_results
# Out:
#                0                1         2                3         4
# 0  Random Forest  88932577.751682  0.742679  98312269.637562  0.666712

# %%
df_models = pd.concat((lr_results, rf_results), axis = 0)
df_models
# Out:
#                    0                1         2                 3         4
# 0  Linear regression  99780339.190658  0.711292  118548810.267941  0.598108
# 0      Random Forest  88932577.751682  0.742679   98312269.637562  0.666712

# %% [markdown]
# # visualize

# %%
import matplotlib.pyplot as plt
plt.scatter(x= y_train, y= y_lr_train_pred)
plt.plot()
# Out:
# []
